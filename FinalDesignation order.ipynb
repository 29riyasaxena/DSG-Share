# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'D:/downloads/Faculty Database2.xlsx')
df.head()
# Out:
# C:\Users\mouli\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   SL No           Unnamed: 1 FACULTY  DATABASE Unnamed: 3  \
# 0   NaN        Faculty Name        Department      Gender
# 1     1       Arindam Biswas               APD          M
# 2     2     Avlokita Agrawal               APD          F
# 3     3        Gaurav Raheja               APD          M
# 4     4  Harshit Sosan Lakra               APD          F
#
#              Unnamed: 4                                         Unnamed: 5  \
# 0          Designation                              Ph.D.  (Research Area)
# 1   Associate Professor                                     Urban Planning
# 2   Associate Professor  Energy Efficiency in Building through passive ...
# 3            Professor   Enabling Environments for the Mobility Impaire...
# 4  Assistant Professor                           Architecture and Planning
#
#                Unnamed: 6 Unnamed: 7           Unnamed: 8  \
# 0  University /Institute    Country   Year of Completion
# 1     University of Tokyo      Japan                 2013
# 2            IIT-Roorkee      India                  2010
# 3            IIT-Roorkee      India                  2008
# 4            IIT-Roorkee      India                  2019
#
#   FACULTY DATABASE WITH PhD RESEARCH AREA, SPECIALIZATION, AREA OF EXPERTISE, SR PROJECTS & TECHNOLOGY TRANSFER   \
# 0                                             E-Mail
# 1                       arindam.biswas@ar.iitr.ac.in
# 2                             avlokita@ar.iitr.ac.in
# 3                        gaurav.raheja@ar.iitr.ac.in
# 4                        harshit.lakra@ar.iitr.ac.in
#
#               Unnamed: 10                                        Unnamed: 11  \
# 0  Telephone Number (off)                            Specialization/Interest
# 1                    4785  Urban and regional governance, Inclusive growt...
# 2                    4776  Energy Efficiency in Buildings, Sustainability...
# 3                    5709  Universal Design, Design for Disabled, Ageing ...
# 4                    4775                 Economic and Community Development
#
#                Unnamed: 12                                        Unnamed: 13  \
# 0  Specialization/Interest                                 Area of Expertise
# 1                      NaN  Smart city development,practicing sustainable ...
# 2                      NaN  Analyzing land surface temperature trends usin...
# 3                      NaN  Accessibility Planning for Higher Education Ca...
# 4                      NaN  Resilient Infrastructure, Green and blue infra...
#
#                                          Unnamed: 14  \
# 0  No. of PhD Supervised / Guided (source: IIT-R ...
# 1                       04 awarded, 8 in Supervision
# 2                         Currently 8 in Supervision
# 3                                   9 in supervision
# 4                                                NaN
#
#                                          Unnamed: 15           Unnamed: 16
# 0  Sponsored Research Projects  (Last Three Years...  Technology Transfer
# 1  SPARC-MHRD, New Delhi: Urban and Regional Ineq...                   NaN
# 2  Indian Knowledge Systems Division AICTE, MOE: ...                   NaN
# 3  Technical universitat Berlin, Germany: SMUS MO...                   NaN
# 4  Dr. Ramdayal Munda Tribal Welfare Research Ins...                   NaN

# %%
df = pd.read_excel(r'D:/downloads/Faculty Database2.xlsx')
df.rename(columns={'Unnamed: 4':'Designation'}, inplace=True)
df['Designation'].unique()
# Out:
# C:\Users\mouli\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# array(['Designation ', 'Associate Professor', 'Professor ',
#        'Assistant Professor ', nan, 'HAG - Professor ',
#        'Professor Emeritus ', 'Retired Faculty ',
#        'Professor of Practice '], dtype=object)

# %%
designation_categories = ['Professor Emeritus ','Professor of Practice ','Retired Faculty ','HAG - Professor ','Professor ','Associate Professor','Assistant Professor ']
df["Designation"] = pd.Categorical(df["Designation"], categories= designation_categories)
df.sort_values(by="Designation",inplace= True)
df.head()
# Out:
#     SL No                   Unnamed: 1 FACULTY  DATABASE Unnamed: 3  \
# 160   153                   Mala Nath                CYD          F
# 38     36                 R. P. Singh              BSBE           M
# 151   144  Bina Gupta (Prof. Emeritus)               CYD          F
# 149   142                  Anil Kumar                CYD          M
# 450   433                    R K Tyagi               MSD          M
#
#                 Designation    Unnamed: 5  \
# 160     Professor Emeritus            NaN
# 38      Professor Emeritus   Microbiology
# 151     Professor Emeritus            NaN
# 149     Professor Emeritus            NaN
# 450  Professor of Practice            NaN
#
#                                    Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 160                                       NaN        NaN        NaN
# 38   Central Drug Research Institute, Lucknow     India        1983
# 151                                       NaN        NaN        NaN
# 149                                       NaN        NaN        NaN
# 450                                       NaN        NaN        NaN
#
#     FACULTY DATABASE WITH PhD RESEARCH AREA, SPECIALIZATION, AREA OF EXPERTISE, SR PROJECTS & TECHNOLOGY TRANSFER   \
# 160                            mala.nath@cy.iitr.ac.in
# 38                               r.singh@bt.iitr.ac.in
# 151                           bina.gupta@cy.iitr.ac.in
# 149                           anil.kumar@cy.iitr.ac.in
# 450                             rk.tyagi@ms.iitr.ac.in
#
#     Unnamed: 10                                        Unnamed: 11  \
# 160        5797  Organotin/organosilicon chemistry, Organotin-b...
# 38         5792  Microbial Biotechnology, Nanobiotechnology, Mi...
# 151        5326  Liquid-liquid extraction and recovery of metal...
# 149        5799  Synthesis of nanomaterials; Supramolecular che...
# 450         NaN  Organisational Strategy and building strategic...
#
#     Unnamed: 12                                        Unnamed: 13  \
# 160         NaN  Applied Organometallic Chemistry, microwave-as...
# 38          NaN  Microbial Biosynthesis, Development of Enginee...
# 151         NaN  Recovery of vanadium (V) from synthetic and re...
# 149         NaN  Kinetics and Photochemistry, Synthesis of Nano...
# 450         NaN  R&D Technology, Investment and risk Management...
#
#     Unnamed: 14                                        Unnamed: 15 Unnamed: 16
# 160         NaN                                                NaN         NaN
# 38          NaN  DBT, Govt. of India: Scaled up Cultivation Iso...         NaN
# 151         NaN                                                NaN         NaN
# 149         NaN                                                NaN         NaN
# 450         NaN                                                NaN         NaN
